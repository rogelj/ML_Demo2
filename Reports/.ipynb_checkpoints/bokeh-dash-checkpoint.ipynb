# %%
from bokeh.io import output_notebook

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f83d56d0-021b-4c74-bc5e-97b1cb2283ca">Loading BokehJS ...</span>
#     </div>

# %%
import numpy as np

from bokeh.layouts import row, widgetbox
from bokeh.models import CustomJS, Slider
from bokeh.plotting import figure, output_file, show, ColumnDataSource

x = np.linspace(0, 10, 500)
y = np.sin(x)

source = ColumnDataSource(data=dict(x=x, y=y))

plot = figure(y_range=(-10, 10), plot_width=400, plot_height=400)

plot.line('x', 'y', source=source, line_width=3, line_alpha=0.6)

callback = CustomJS(args=dict(source=source), code="""
    var data = source.data;
    var A = amp.value;
    var k = freq.value;
    var phi = phase.value;
    var B = offset.value;
    x = data['x']
    y = data['y']
    for (i = 0; i < x.length; i++) {
        y[i] = B + A*Math.sin(k*x[i]+phi);
    }
    source.trigger('change');
""")

amp_slider = Slider(start=0.1, end=10, value=1, step=.1,
                    title="Amplitude", callback=callback)
callback.args["amp"] = amp_slider

freq_slider = Slider(start=0.1, end=10, value=1, step=.1,
                     title="Frequency", callback=callback)
callback.args["freq"] = freq_slider

phase_slider = Slider(start=0, end=6.4, value=0, step=.1,
                      title="Phase", callback=callback)
callback.args["phase"] = phase_slider

offset_slider = Slider(start=-5, end=5, value=0, step=.1,
                       title="Offset", callback=callback)
callback.args["offset"] = offset_slider

layout = row(
    plot,
    widgetbox(amp_slider, freq_slider, phase_slider, offset_slider),
)

output_file("slider.html", title="slider.py example")

# %% [markdown]
# ## Interactive dashboard
#
# Try changing the sliders to see how it impacts the wave function

# %%
show(layout)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c7179772-3b87-46b8-bc99-b8aa47358efa"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("c7179772-3b87-46b8-bc99-b8aa47358efa").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c7179772-3b87-46b8-bc99-b8aa47358efa");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c7179772-3b87-46b8-bc99-b8aa47358efa' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c8019cbf-9367-4b3a-aca8-a37774128669":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[500]},"y":{"__ndarray__":"...","dtype":"float64","shape":[500]}}},"id":"e66e33b0-77c3-4908-b31f-5f5fa807d46b","type":"ColumnDataSource"},{"attributes":{"callback":{"id":"eb307d30-4c85-4cd7-a7b4-943684809b4d","type":"CustomJS"},"end":5,"start":-5,"title":"Offset","value":0},"id":"b8ad1221-862e-4bc4-8738-e7c33c995786","type":"Slider"},{"attributes":{"plot":{"id":"ffcbd08d-7049-4e6f-b29e-e2de9b2ae7c6","subtype":"Figure","type":"Plot"}},"id":"eda31209-547d-42f8-b358-419abfc88464","type":"PanTool"},{"attributes":{"callback":null,"end":10,"start":-10},"id":"13262e37-329c-4bd3-a4be-2d0e716c1c67","type":"Range1d"},{"attributes":{"line_alpha":{"value":0.6},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"95278fd0-2ff0-4329-a9c9-c5027cf20f18","type":"Line"},{"attributes":{"callback":null},"id":"90e728e5-5f18-4eec-bae0-8e689ffa277b","type":"DataRange1d"},{"attributes":{"callback":{"id":"eb307d30-4c85-4cd7-a7b4-943684809b4d","type":"CustomJS"},"end":6.4,"title":"Phase","value":0},"id":"87ed07a9-8464-4ce8-a99f-7320bb29cb8f","type":"Slider"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"1a23eda2-bd17-4723-8851-21e4770168af","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"ffcbd08d-7049-4e6f-b29e-e2de9b2ae7c6","subtype":"Figure","type":"Plot"},"ticker":{"id":"23e0b9ec-5b8b-47ec-a6e3-af28deff3e53","type":"BasicTicker"}},"id":"19ff4318-5009-4ca2-a9d5-5950c192ccdf","type":"Grid"},{"attributes":{"callback":{"id":"eb307d30-4c85-4cd7-a7b4-943684809b4d","type":"CustomJS"},"end":10,"start":0.1,"title":"Amplitude","value":1},"id":"9631ec45-d03d-4586-b813-72df13c05515","type":"Slider"},{"attributes":{},"id":"1e6030f6-83cd-4665-8cf8-dd2b7a0cd67d","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"1e6030f6-83cd-4665-8cf8-dd2b7a0cd67d","type":"BasicTickFormatter"},"plot":{"id":"ffcbd08d-7049-4e6f-b29e-e2de9b2ae7c6","subtype":"Figure","type":"Plot"},"ticker":{"id":"23e0b9ec-5b8b-47ec-a6e3-af28deff3e53","type":"BasicTicker"}},"id":"b6eae76c-e6ee-4493-8b54-440cf52aae54","type":"LinearAxis"},{"attributes":{"overlay":{"id":"1a23eda2-bd17-4723-8851-21e4770168af","type":"BoxAnnotation"},"plot":{"id":"ffcbd08d-7049-4e6f-b29e-e2de9b2ae7c6","subtype":"Figure","type":"Plot"}},"id":"f977820f-42b4-4a15-ab84-b00d9596e965","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"e66e33b0-77c3-4908-b31f-5f5fa807d46b","type":"ColumnDataSource"},"glyph":{"id":"95278fd0-2ff0-4329-a9c9-c5027cf20f18","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"0eac811b-1c03-45ce-a5f6-5e690f501267","type":"Line"},"selection_glyph":null},"id":"8781c062-7c5a-42f7-8786-a6b4b987612a","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"ffcbd08d-7049-4e6f-b29e-e2de9b2ae7c6","subtype":"Figure","type":"Plot"}},"id":"0adbfa26-96b0-41ea-aa6d-e523f9967e54","type":"SaveTool"},{"attributes":{"dimension":1,"plot":{"id":"ffcbd08d-7049-4e6f-b29e-e2de9b2ae7c6","subtype":"Figure","type":"Plot"},"ticker":{"id":"8437adfb-b722-491e-932e-8d3f65aca253","type":"BasicTicker"}},"id":"cf2f0bad-74b7-469e-9537-3c7ff57e8bcb","type":"Grid"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"eda31209-547d-42f8-b358-419abfc88464","type":"PanTool"},{"id":"d8785eaf-07e7-4600-b870-f1ed7ea3b60d","type":"WheelZoomTool"},{"id":"f977820f-42b4-4a15-ab84-b00d9596e965","type":"BoxZoomTool"},{"id":"0adbfa26-96b0-41ea-aa6d-e523f9967e54","type":"SaveTool"},{"id":"0bb87ca4-f9fa-4c4a-bd2a-92161b6289d7","type":"ResetTool"},{"id":"227 ...

# %%
import pandas as pd

from bokeh.layouts import row, widgetbox
from bokeh.models import Select
from bokeh.palettes import Spectral5
from bokeh.plotting import curdoc, figure, show
from bokeh.sampledata.autompg import autompg

df = autompg.copy()

SIZES = list(range(6, 22, 3))
COLORS = Spectral5
ORIGINS = ['North America', 'Europe', 'Asia']

# data cleanup
df.cyl = [str(x) for x in df.cyl]
df.origin = [ORIGINS[x-1] for x in df.origin]

df['year'] = [str(x) for x in df.yr]
del df['yr']

df['mfr'] = [x.split()[0] for x in df.name]
df.loc[df.mfr=='chevy', 'mfr'] = 'chevrolet'
df.loc[df.mfr=='chevroelt', 'mfr'] = 'chevrolet'
df.loc[df.mfr=='maxda', 'mfr'] = 'mazda'
df.loc[df.mfr=='mercedes-benz', 'mfr'] = 'mercedes'
df.loc[df.mfr=='toyouta', 'mfr'] = 'toyota'
df.loc[df.mfr=='vokswagen', 'mfr'] = 'volkswagen'
df.loc[df.mfr=='vw', 'mfr'] = 'volkswagen'
del df['name']

columns = sorted(df.columns)
discrete = [x for x in columns if df[x].dtype == object]
continuous = [x for x in columns if x not in discrete]
quantileable = [x for x in continuous if len(df[x].unique()) > 20]


def create_figure():
    xs = df[x.value].values
    ys = df[y.value].values
    x_title = x.value.title()
    y_title = y.value.title()

    kw = dict()
    if x.value in discrete:
        kw['x_range'] = sorted(set(xs))
    if y.value in discrete:
        kw['y_range'] = sorted(set(ys))
    kw['title'] = "%s vs %s" % (x_title, y_title)

    p = figure(plot_height=600, plot_width=800, tools='pan,box_zoom,reset', **kw)
    p.xaxis.axis_label = x_title
    p.yaxis.axis_label = y_title

    if x.value in discrete:
        p.xaxis.major_label_orientation = pd.np.pi / 4

    sz = 9
    if size.value != 'None':
        groups = pd.qcut(df[size.value].values, len(SIZES))
        sz = [SIZES[xx] for xx in groups.codes]

    c = "#31AADE"
    if color.value != 'None':
        groups = pd.qcut(df[color.value].values, len(COLORS))
        c = [COLORS[xx] for xx in groups.codes]
    p.circle(x=xs, y=ys, color=c, size=sz, line_color="white", alpha=0.6, hover_color='white', hover_alpha=0.5)

    return p


def update(attr, old, new):
    layout.children[1] = create_figure()


x = Select(title='X-Axis', value='mpg', options=columns)
x.on_change('value', update)

y = Select(title='Y-Axis', value='hp', options=columns)
y.on_change('value', update)

size = Select(title='Size', value='None', options=['None'] + quantileable)
size.on_change('value', update)

color = Select(title='Color', value='None', options=['None'] + quantileable)
color.on_change('value', update)

controls = widgetbox([x, y, color, size], width=200)
layout = row(controls, create_figure())

curdoc().add_root(layout)
curdoc().title = "Crossfilter"

# %%
show(layout, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d61b3e56-ea08-4502-80a2-3442f14fabb5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("d61b3e56-ea08-4502-80a2-3442f14fabb5").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("9140f60a-7e09-4826-8dd8-951fd4f2364e", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d61b3e56-ea08-4502-80a2-3442f14fabb5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd61b3e56-ea08-4502-80a2-3442f14fabb5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"959ee831-5ca6-48f2-9484-a3050d0e0bb7":{"roots":{"references":[{"attributes":{"callback":null},"id":"3122ebf0-9cb2-489c-b6a0-442d1adcc6e5","type":"DataRange1d"},{"attributes":{"children":[{"id":"4d1e353f-3236-4d8d-a78f-9b41653d71bf","type":"WidgetBox"},{"id":"5c52f43d-a293-4a3e-9391-a9a2152fadd3","subtype":"Figure","type":"Plot"}]},"id":"25ac343b-c3b7-4123-94c7-f5d54bec2e55","type":"Row"},{"attributes":{},"id":"3a7a89f7-02e7-4ade-a9f5-7688787ccc41","type":"BasicTicker"},{"attributes":{"plot":{"id":"5c52f43d-a293-4a3e-9391-a9a2152fadd3","subtype":"Figure","type":"Plot"}},"id":"d4279c7b-d1e3-4fdf-8fa6-bcb565d30633","type":"ResetTool"},{"attributes":{"data_source":{"id":"0b2ff52f-14bf-4042-aa11-dcf30172b69e","type":"ColumnDataSource"},"glyph":{"id":"37e27659-80bb-4c68-9373-9314dee9c0b2","type":"Circle"},"hover_glyph":{"id":"df46c52b-07cf-4d15-8af8-ff2c06ef1329","type":"Circle"},"nonselection_glyph":{"id":"9def29d0-8ebe-4c72-b338-2cab9e274971","type":"Circle"},"selection_glyph":null},"id":"a90ffed6-7649-413c-b0f7-063c7526df2f","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"04977487-2159-46b6-86a4-bcb1f45fdc57","type":"DataRange1d"},{"attributes":{"callback":null,"options":["None","accel","displ","hp","mpg","weight"],"title":"Color","value":"None"},"id":"b3bcaeee-d0fa-4a22-bdda-63c91f64e4e3","type":"Select"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"0c640188-cf70-431c-8e5d-bec6337b090d","type":"BoxAnnotation"},{"attributes":{"axis_label":"Mpg","formatter":{"id":"cd22ae21-50df-40a7-9505-8385c25e32de","type":"BasicTickFormatter"},"plot":{"id":"5c52f43d-a293-4a3e-9391-a9a2152fadd3","subtype":"Figure","type":"Plot"},"ticker":{"id":"3a7a89f7-02e7-4ade-a9f5-7688787ccc41","type":"BasicTicker"}},"id":"10ce5a95-b154-4023-819e-8e2381084e25","type":"LinearAxis"},{"attributes":{"callback":null,"options":["accel","cyl","displ","hp","mfr","mpg","origin","weight","year"],"title":"Y-Axis","value":"hp"},"id":"7fc70694-3e64-4d1c-969e-10e1a7aaba2d","type":"Select"},{"attributes":{"axis_label":"Hp","formatter":{"id":"10f6df3e-3d5f-4828-846a-c0ec3bfa536a","type":"BasicTickFormatter"},"plot":{"id":"5c52f43d-a293-4a3e-9391-a9a2152fadd3","subtype":"Figure","type":"Plot"},"ticker":{"id":"657054c7-8288-47e4-8673-5927cf6a97a6","type":"BasicTicker"}},"id":"3b6b02b8-7650-4826-bae4-0fee3167994a","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"5c52f43d-a293-4a3e-9391-a9a2152fadd3","subtype":"Figure","type":"Plot"},"ticker":{"id":"657054c7-8288-47e4-8673-5927cf6a97a6","type":"BasicTicker"}},"id":"e1cfa24c-b1c8-458f-9fec-7976dc39f0f9","type":"Grid"},{"attributes":{"plot":{"id":"5c52f43d-a293-4a3e-9391-a9a2152fadd3","subtype":"Figure","type":"Plot"},"ticker":{"id":"3a7a89f7-02e7-4ade-a9f5-7688787ccc41","type":"BasicTicker"}},"id":"9001d0a9-0a57-420e-b8bc-4b6814cf0888","type":"Grid"},{"attributes":{"plot":null,"text":"Mpg vs Hp"},"id":"f316f8d1-a4b2-4bcf-afb5-44ac377a337a","type":"Title"},{"attributes":{},"id":"10f6df3e-3d5f-4828-846a-c0ec3bfa536a","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"5c52f43d-a293-4a3e-9391-a9a2152fadd3","subtype":"Figure","type":"Plot"}},"id":"fb44f9c4-ea68-4679-80aa-08733bf6a5f8","type":"PanTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":9},"x":{"field":"x"},"y":{"field":"y"}},"id":"9def29d0-8ebe-4c72-b338-2cab9e274971","type":"Circle"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"fb44f9c4-ea68-4679-80aa-08733bf6a5f8","type":"PanTool"},{"id":"9e1dbdd0-c0de-43f0-8965-fc3c21ffdaf2","type":"BoxZoomTool"},{"id":"d4279c7 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[19]</strong>&gt;</code></p>
